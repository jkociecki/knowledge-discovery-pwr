# %% [markdown]
# - Indeks: 272711
# - Github: @jkociecki

# %%
import sys
import os

sys.path.insert(0, os.path.dirname(os.getcwd()))

from src.utils import Player, BoardManager

# %%
players = [
    Player(nickname="a", points=8, settlements=3),
    Player(nickname="b", points=10, settlements=4),
    Player(nickname="c", points=5, settlements=2)
]

board_manager = BoardManager(players)

print(board_manager.get_available_resources())

winners = board_manager.check_victory(win_condition=10)
print(f"(>10 pkt): {winners}")

print("Gracze:")
for p in board_manager.players:
    print(f"  {p.nickname}: {p.points} pkt, {p.settlements} osad")
# Out:
# {'Lumber', 'Brick', 'Wool', 'Ore'}
# (>10 pkt): ['b']
# Gracze:
#   a: 8 pkt, 3 osad
#   b: 10 pkt, 4 osad
#   c: 5 pkt, 2 osad
